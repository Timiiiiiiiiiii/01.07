# %% [markdown]
# ### 데이터프레임의 결합
#
# - 유니언 결합
#     - 가장 단순한 결합의 형태
#     - 단순하게 행을 결합, 열을 결합
# - 조인 결합
#     - 특정한 조건에 맞춰 데이터들을 열 결합
#     - 데이터프레임 + 데이터프레임 결합할때 -> 특정 컬럼의 데이터들이 같은 값들로 이루어져있을떄 열을 추가함

# %%
import pandas as pd

# %%
data = {
    'name' : ['test','test2','test3'],
    'age' : [20,30,40]
}
df1 = pd.DataFrame(data)
df1
# Out:
#     name  age
# 0   test   20
# 1  test2   30
# 2  test3   40

# %%
data2 = {
    'name' : ['test4', 'test5'],
    'loc' : ['seoul','busan']
}
df2 = pd.DataFrame(data2)
df2
# Out:
#     name    loc
# 0  test4  seoul
# 1  test5  busan

# %%
# 단순하게 행을 결합
# pandas 안에 있는 concat([데이터프레임1, 데이터프레임2, ...], axis={0|1, rows|columns}, ignore_index={bool})
# axis 매개변수 : 행결합이냐 열결합을 지정
# ignore_index 매개변수 : 기본값은 False, 행을 결합할때 index를 초기화 할 것인가?, 열을 결합할때는 컬럼을 초기화 할것인가를 지정

pd.concat([df1,df2], axis=0)
# Out:
#     name   age    loc
# 0   test  20.0    NaN
# 1  test2  30.0    NaN
# 2  test3  40.0    NaN
# 0  test4   NaN  seoul
# 1  test5   NaN  busan

# %%
pd.concat([df1,df2], axis=0, ignore_index=False)
# Out:
#     name   age    loc
# 0   test  20.0    NaN
# 1  test2  30.0    NaN
# 2  test3  40.0    NaN
# 0  test4   NaN  seoul
# 1  test5   NaN  busan

# %%
pd.concat([df1,df2], axis=0, ignore_index=True)
# Out:
#     name   age    loc
# 0   test  20.0    NaN
# 1  test2  30.0    NaN
# 2  test3  40.0    NaN
# 3  test4   NaN  seoul
# 4  test5   NaN  busan

# %%
# if ignore_index가 기억이 안나면
pd.concat([df1,df2], axis=0).reset_index(drop=True)
# Out:
#     name   age    loc
# 0   test  20.0    NaN
# 1  test2  30.0    NaN
# 2  test3  40.0    NaN
# 3  test4   NaN  seoul
# 4  test5   NaN  busan

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     name  age   name    loc
# 0   test   20  test4  seoul
# 1  test2   30  test5  busan
# 2  test3   40    NaN    NaN

# %%
# index결과과 다를때
df2.index = [5,6]
df2
# Out:
#     name    loc
# 5  test4  seoul
# 6  test5  busan

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     name   age   name    loc
# 0   test  20.0    NaN    NaN
# 1  test2  30.0    NaN    NaN
# 2  test3  40.0    NaN    NaN
# 5    NaN   NaN  test4  seoul
# 6    NaN   NaN  test5  busan

# %%
pd.concat([df1, df2], axis=1, ignore_index= True)
# Out:
#        0     1      2      3
# 0   test  20.0    NaN    NaN
# 1  test2  30.0    NaN    NaN
# 2  test3  40.0    NaN    NaN
# 5    NaN   NaN  test4  seoul
# 6    NaN   NaN  test5  busan

# %%
data3 = {
    'name' : ['test6', 'test7'],
    'age' : [25,35],
    'loc' : ['ulsan', 'mokpo']         
}
df3 = pd.DataFrame(data3)
df3
# Out:
#     name  age    loc
# 0  test6   25  ulsan
# 1  test7   35  mokpo

# %%
# 3개의 데이터프레임을 행 결합
pd.concat([df1,df2,df3], axis=0)
# Out:
#     name   age    loc
# 0   test  20.0    NaN
# 1  test2  30.0    NaN
# 2  test3  40.0    NaN
# 5  test4   NaN  seoul
# 6  test5   NaN  busan
# 0  test6  25.0  ulsan
# 1  test7  35.0  mokpo

# %%
# 특정한 조건에 맞춰서 열 결합 : 조인 결합
# pandas 안에 있는 merge()
# merge(데이터프레임1, 데이터프레임2, on = {컬럼명(조건)}, how = {left | right | inner | outer 중에 하나 들어감})

# %%
data = {
    'id' : ['test','test2', 'test3', 'test4'],
    'item' : ['A', 'B', 'A', 'D' ]
}
df1 = pd.DataFrame(data)
df1
# Out:
#       id item
# 0   test    A
# 1  test2    B
# 2  test3    A
# 3  test4    D

# %%
data2 = {
    'item_name' : ['A', 'B', 'C'],
    'price' : [100,200,300]
}
df2 = pd.DataFrame(data2)
df2
# Out:
#   item_name  price
# 0         A    100
# 1         B    200
# 2         C    300

# %%
# 데이터프레임에서 조건 컬럼의 이름이 같은 경우
pd.merge(df1,df2, on='item', how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\python_Timi\ezen_python\231210\01_dataframe.ipynb 셀 18 line 2
#       <a href='vscode-notebook-cell:/d%3A/python_Timi/ezen_python/231210/01_dataframe.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # 데이터프레임에서 조건 컬럼의 이름이 같은 경우
# ----> <a href='vscode-notebook-cell:/d%3A/python_Timi/ezen_python/231210/01_dataframe.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> pd.merge(df1,df2, on='item', how='inner')
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:169, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     154     return _cross_merge(
#     155         left_df,
#     156         right_df,
#    (...)
#     166         copy=copy,
#     167     )
#     168 else:
# --> 169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#     172         how=how,
#     173         on=on,
#     174         left_on=left_on,
#     175         right_on=right_on,
#     176         left_index=left_index,
#     177         right_index=right_index,
#     178         sort=sort,
#     179         suffixes=suffixes,
#     180         indicator=indicator,
#     181         validate=validate,
#     182     )
#     183     return op.get_result(copy=copy)
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:791, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     781     raise MergeError(msg)
#     783 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     785 (
#     786     self.left_join_keys,
#     787     self.right_join_keys,
#     788     self.join_names,
#     789     left_drop,
#     790     right_drop,
# --> 791 ) = self._get_merge_keys()
#     793 if left_drop:
#     794     self.left = self.left._drop_labels_or_levels(left_drop)
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1269, in _MergeOperation._get_merge_keys(self)
#    1267 rk = cast(Hashable, rk)
#    1268 if rk is not None:
# -> 1269     right_keys.append(right._get_label_or_level_values(rk))
#    1270 else:
#    1271     # work-around for merge_asof(right_index=True)
#    1272     right_keys.append(right.index._values)
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:1844, in NDFrame._get_label_or_level_values(self, key, axis)
#    1842     values = self.axes[axis].get_level_values(key)._values
#    1843 else:
# -> 1844     raise KeyError(key)
#    1846 # Check for duplicates
#    1847 if values.ndim > 1:
#
# KeyError: 'item'

# %%
pd.merge(df1,df2, on='item', how='left')
# Out:
#       id item  price
# 0   test    A  100.0
# 1  test2    B  200.0
# 2  test3    A  100.0
# 3  test4    D    NaN

# %%
pd.merge(df1,df2, on='item', how='right')
# Out:
#       id item  price
# 0   test    A    100
# 1  test3    A    100
# 2  test2    B    200
# 3    NaN    C    300

# %%
pd.merge(df1,df2, on='item', how='outer')
# Out:
#       id item  price
# 0   test    A  100.0
# 1  test3    A  100.0
# 2  test2    B  200.0
# 3  test4    D    NaN
# 4    NaN    C  300.0

# %%
# 데이터프레임에서 조건 컬럼의 이름이 다른 경우
pd.merge(df1,df2, left_on='item', right_on='item_name', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\python_Timi\ezen_python\231210\01_dataframe.ipynb 셀 22 line 2
#       <a href='vscode-notebook-cell:/d%3A/python_Timi/ezen_python/231210/01_dataframe.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # 데이터프레임에서 조건 컬럼의 이름이 다른 경우
# ----> <a href='vscode-notebook-cell:/d%3A/python_Timi/ezen_python/231210/01_dataframe.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> pd.merge(df1,df2, left_on='item', right_on='item_name', how='left')
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:169, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     154     return _cross_merge(
#     155         left_df,
#     156         right_df,
#    (...)
#     166         copy=copy,
#     167     )
#     168 else:
# --> 169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#     172         how=how,
#     173         on=on,
#     174         left_on=left_on,
#     175         right_on=right_on,
#     176         left_index=left_index,
#     177         right_index=right_index,
#     178         sort=sort,
#     179         suffixes=suffixes,
#     180         indicator=indicator,
#     181         validate=validate,
#     182     )
#     183     return op.get_result(copy=copy)
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:791, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     781     raise MergeError(msg)
#     783 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     785 (
#     786     self.left_join_keys,
#     787     self.right_join_keys,
#     788     self.join_names,
#     789     left_drop,
#     790     right_drop,
# --> 791 ) = self._get_merge_keys()
#     793 if left_drop:
#     794     self.left = self.left._drop_labels_or_levels(left_drop)
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1269, in _MergeOperation._get_merge_keys(self)
#    1267 rk = cast(Hashable, rk)
#    1268 if rk is not None:
# -> 1269     right_keys.append(right._get_label_or_level_values(rk))
#    1270 else:
#    1271     # work-around for merge_asof(right_index=True)
#    1272     right_keys.append(right.index._values)
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:1844, in NDFrame._get_label_or_level_values(self, key, axis)
#    1842     values = self.axes[axis].get_level_values(key)._values
#    1843 else:
# -> 1844     raise KeyError(key)
#    1846 # Check for duplicates
#    1847 if values.ndim > 1:
#
# KeyError: 'item_name'

# %%
data3 = {
    'id' : ['test', 'test2', 'test3'],
    'gold' : [10000, 5000, 0]
}
df3 = pd.DataFrame(data3)
df3
# Out:
#       id   gold
# 0   test  10000
# 1  test2   5000
# 2  test3      0

# %%
# df1,df2.df3 모두 조인 결합
# df2의 컬럼의 이름을 변경
df2.rename(columns={
    'item_name' : 'item'
})
# Out:
#   item  price
# 0    A    100
# 1    B    200
# 2    C    300

# %%
df2.rename(columns={
    'item_name' : 'item'
}, inplace=True)

# %%
merge_data = pd.merge(df1,df2, on='item', how='left')
merge_data
# Out:
#       id item  price
# 0   test    A  100.0
# 1  test2    B  200.0
# 2  test3    A  100.0
# 3  test4    D    NaN

# %%
df3
# Out:
#       id   gold
# 0   test  10000
# 1  test2   5000
# 2  test3      0

# %%
pd.merge(merge_data, df3, on='id', how='left')
# Out:
#       id item  price     gold
# 0   test    A  100.0  10000.0
# 1  test2    B  200.0   5000.0
# 2  test3    A  100.0      0.0
# 3  test4    D    NaN      NaN
